# %%
import requests
from bs4 import BeautifulSoup
from csv import writer

# %%
response_petrol = requests.get('https://www.mypetrolprice.com/petrol-price-in-india.aspx')
request_petrol = requests.get('https://www.mypetrolprice.com/petrol-price-in-india.aspx').text

# %%
print(request_petrol)
# Out:
# <!DOCTYPE html>
#
# <html xmlns="http://www.w3.org/1999/xhtml" itemscope itemtype="http://schema.org/WebPage" prefix="og: http://ogp.me/ns#">
# <head><meta name="google-site-verification" content="mgzLIL0RxOK_peobVIpsl28RMogh04-9Ea9YfNbYcCM" /><meta name="y_key" content="3cb4dbb31c456d7d" /><meta name="msvalidate.01" content="B3066B21C8BB06A15185D558C8873DEE" /><title>
# 	Petrol Price in India | Cost of Petrol in India
# </title><meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=6" /><link rel="shortcut icon" href="https://www.mypetrolprice.com/favicon.ico" type="image/x-icon" />
#     <style>
#         /*site.css*/
# ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(request_petrol, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml">
# <head><meta content="mgzLIL0RxOK_peobVIpsl28RMogh04-9Ea9YfNbYcCM" name="google-site-verification"/><meta content="3cb4dbb31c456d7d" name="y_key"/><meta content="B3066B21C8BB06A15185D558C8873DEE" name="msvalidate.01"/><title>
# 	Petrol Price in India | Cost of Petrol in India
# </title><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, maximum-scale=6" name="viewport"/><link href="https://www.mypetrolprice.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <style>
#         /*site.css*/
# ...

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml">
# <head><meta content="mgzLIL0RxOK_peobVIpsl28RMogh04-9Ea9YfNbYcCM" name="google-site-verification"/><meta content="3cb4dbb31c456d7d" name="y_key"/><meta content="B3066B21C8BB06A15185D558C8873DEE" name="msvalidate.01"/><title>
# 	Petrol Price in India | Cost of Petrol in India
# </title><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, maximum-scale=6" name="viewport"/><link href="https://www.mypetrolprice.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <style>
#         /*site.css*/
# ...

# %%
print(soup.title)
# Out:
# <title>
# 	Petrol Price in India | Cost of Petrol in India
# </title>

# %%
print(soup.title.string)
# Out:
# 	Petrol Price in India | Cost of Petrol in India

# %%
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /
# https://www.mypetrolprice.com/petrol-price-in-india.aspx
# https://www.mypetrolprice.com/diesel-price-in-india.aspx
# https://www.mypetrolprice.com/cng-price-in-india.aspx
# https://www.mypetrolprice.com/autogas-autolpg-price-in-india.aspx
# https://www.mypetrolprice.com/lpg-price-in-india.aspx
# https://www.mypetrolprice.com/All-fuel-prices-in-india.aspx
# https://www.mypetrolprice.com/Fuel-Price-Calculator
# https://www.mypetrolprice.com/fuel-price-chart.aspx
# https://www.mypetrolprice.com/Fuel-Price-Map-Of-India
# https://www.mypetrolprice.com/
# https://www.mypetrolprice.com/petrol-price-in-india.aspx
# https://www.mypetrolprice.com/0/1/Petrol-Prices-in-Andaman_and_Nicobar_Islands
# https://www.mypetrolprice.com/29/0/Port_Blair-Petrol-Price-Chart
# https://www.mypetrolprice.com/29/Petrol-price-in-Port_Blair
# https://www.mypetrolprice.com/0/2/Petrol-Prices-in-Andhra_Pradesh
# https://www.mypetrolprice.com/123/0/Anantapur-Petrol-Price-Chart
# ...

# %%
soup_petrol = BeautifulSoup(response_petrol.text, 'html.parser')
mydivs_petrol = soup_petrol.findAll("div", {"class": "SF"})
print("petrol_prices")
# printing petrol prices
for div in mydivs_petrol:
    price = div.find("div", {"class": "txtC"}).text[2:8]
    city = div.find("div", {"class": "CH"}).find_all(
        "a")[1]["href"].split('/')[4].split('-')[3].replace('_', ' ')
    print(city, price)
# Out:
# petrol_prices
# Port Blair  82.42
# Anantapur  109.4
# Chittoor  110.4
# Eluru  109.7
# Guntur  109.4
# Hyderabad  107.3
# Kadapa  108.5
# Kakinada  109.8
# Kurnool  109.9
# Machilipatnam  109.7
# Nellore  109.9
# Ongole  108.5
# Srikakulam  109.3
# Vizag  108.2
# Vizianagaram  108.8
# Itanagar  90.82
# Barpeta  96.48
# Dibrugarh  96.84
# Golaghat  96.25
# Guwahati  96.12
# Jorhat  96.58
# Nagaon  96.94
# Nalbari  96.64
# Sibsagar  97.03
# Silchar  96.66
# Tezpur  96.67
# Araria  107.0
# Arrah  106.1
# Aurangabad  106.6
# Banka  106.2
# Begusarai  104.8
# Bettiah  106.9
# Bhagalpur  105.9
# Bihar Sharif  105.8
# Buxar  106.6
# Chapra  106.5
# Darbhanga  105.8
# Gaya  106.2
# Hajipur  105.2
# Jamui  106.1
# Jehanabad  105.7
# Katihar  106.6
# Khagaria  105.2
# Kishanganj  107.3
# Lakhisarai  106.2
# Madhepura  106.2
# Madhubani  106.1
# Motihari  106.5
# Munger  105.3
# Muzaffarpur  105.8
# Nawada  106.0
# Patna  105.1
# Purnia  106.6
# Samastipur  105.3
# Sasaram  106.6
# ...

# %%
response_diesel = requests.get(
    'https://www.mypetrolprice.com/diesel-price-in-india.aspx')

# %%
soup_diesel = BeautifulSoup(response_diesel.text, 'html.parser')
mydivs_diesel = soup_diesel.findAll("div", {"class": "SF"})

# %%
print("diesel_prices")
diesel_dict={}
# printing diesel prices
for div in mydivs_diesel:
    price = div.find("div", {"class": "txtC"}).text[2:8]
    city = cost = div.find("div", {"class": "CH"}).find_all(
        "a")[1]["href"].split('/')[4].split('-')[3].replace('_', ' ')
    print(city, price)
    diesel_dict.update({city:price})
# Out:
# diesel_prices
# Port Blair  78.01
# Anantapur  97.25
# Chittoor  98.14
# Eluru  97.60
# Guntur  97.34
# Hyderabad  95.63
# Kadapa  96.40
# Kakinada  97.61
# Kurnool  97.74
# Machilipatnam  97.58
# Nellore  97.75
# Ongole  96.46
# Srikakulam  97.16
# Vizag  96.16
# Vizianagaram  96.71
# Itanagar  80.34
# Barpeta  88.72
# Dibrugarh  89.07
# Golaghat  88.49
# Guwahati  88.36
# Jorhat  88.82
# Nagaon  89.15
# Nalbari  88.88
# Sibsagar  89.23
# Silchar  88.94
# Tezpur  88.92
# Araria  93.76
# Arrah  92.91
# Aurangabad  93.46
# Banka  93.03
# Begusarai  91.74
# Bettiah  93.70
# Bhagalpur  92.74
# Bihar Sharif  92.62
# Buxar  93.45
# Chapra  93.28
# Darbhanga  92.66
# Gaya  93.05
# Hajipur  92.10
# Jamui  92.92
# Jehanabad  92.61
# Katihar  93.43
# Khagaria  92.10
# Kishanganj  94.05
# Lakhisarai  93.00
# Madhepura  92.97
# Madhubani  92.97
# Motihari  93.36
# Munger  92.22
# Muzaffarpur  92.65
# Nawada  92.88
# Patna  92.03
# Purnia  93.41
# Samastipur  92.15
# Sasaram  93.40
# ...
